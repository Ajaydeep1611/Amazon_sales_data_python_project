# %% [markdown]
# # IMPORTING USEFULL MODULES AND LIBRARIES

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# #IMPORTING DATA IN NOTEBOOK

# %%
dataset=pd.read_csv('/content/amazon sales data of 2022.csv')
# Out:
# <ipython-input-2-0364bf27f0fe>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset=pd.read_csv('/content/amazon sales data of 2022.csv')

# %%
dataset
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# # DROPING Unnamed 22,fullfilled-by, ship-country,currency,sales channel

# %%
dataset.drop('Unnamed: 22',axis=1,inplace=True)
dataset.drop('fulfilled-by',axis=1,inplace=True)
dataset.drop('ship-country',axis=1,inplace=True)
dataset.drop('currency',axis=1,inplace=True)
dataset.drop('Sales Channel ',axis=1,inplace=True)

# %%
dataset
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# #DROP THE DUPLICATES VALUES FROM 'Order_ID' AND 'ASIN'

# %%
dataset=dataset.drop_duplicates(subset=['Order ID','ASIN'])

# %% [markdown]
# # Columns fillna()
# ## Courier Status - will fill missing with 'Unknown'
# ## promotion-ids - will fill missing with 'No Promotion'
# ## Amount - will fill missing with 0, since 97% of of all Orders with missing Amount are cancelled

# %%
fill_na_value={'Courier Status':'Unknown','promotion-ids':'No Promotion','Amount':0}
dataset=dataset.fillna(value=fill_na_value)
dataset
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# #Rename the columns 'B2B' as 'Customer_type' and 'Amount' as 'Order_Amount'

# %%
column_rename_dict={'B2B':'Customer_type','Amount':'Order_Amount_($)'}
dataset=dataset.rename(columns=column_rename_dict)
dataset
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# #### B2B - changing to customer_type and changing the values to business and customer

# %%
dataset['Customer_type']=dataset['Customer_type'].astype(str)
dataset['Customer_type']=dataset['Customer_type'].str.strip().replace({'True':"Business",'False':'Customer'})
dataset
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
# CHANGE AND CONVERTING INR ITNO $
exchange_rate=0.0120988
dataset['Order_Amount_($)']=(dataset['Order_Amount_($)'].apply(lambda x:x*exchange_rate)).round(2)

# %%
dataset
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
#CHANGE THE DATE FORMAT AND SLECT THE DATE FROM ' 01-04-2022 TO 29-06-2022 '
dataset["Date"]=pd.to_datetime(dataset["Date"])
s='2022-04-01'
e='2022-06-29'
dataset=dataset.query('Date >=@s and Date <=@e')
dataset
# Out:
# <ipython-input-12-f03c005decb0>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset["Date"]=pd.to_datetime(dataset["Date"])
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  128971  402-9551604-7544318 2022-05-31                       Shipped
# ...

# %%
 #ADD MONTH COLUMN
 dataset['Month']=dataset['Date'].dt.month_name()
dataset
# Out:
# <ipython-input-13-017eb32027c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Month']=dataset['Date'].dt.month_name()
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# ...

# %%
size_order=['S','M','L','XL','XS','XXl','3Xl','4XL','5XL','6XL','FREE']
dataset['size']=pd.Categorical(dataset['Size'],categories=size_order,ordered=True)
dataset
# Out:
# <ipython-input-14-caa4144ed3d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['size']=pd.Categorical(dataset['Size'],categories=size_order,ordered=True)
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# ...

# %%
#FILL THE REMAING NA VALUES IN THESE COLUMNS
fill_na_values = {'ship-state':'Unknown','ship-postal-code':'Unknown','ship-city':'Unknown'}
dataset=dataset.fillna(value=fill_na_values)

# %%
grouped_dataset=dataset.groupby('Category')['Order_Amount_($)'].sum()
grouped_dataset
# Out:
# Category
# Blouse             5542.42
# Bottom             1823.10
# Dupatta              11.07
# Ethnic Dress       9559.10
# Saree              1499.54
# Set              473634.23
# Top               64638.34
# Western Dress    135605.96
# kurta            257266.80
# Name: Order_Amount_($), dtype: float64

# %%
 #TOP 3 CATEGORIES
 top3_categories=grouped_dataset.nlargest(3)
print(top3_categories)
# Out:
# Category
# Set              473634.23
# kurta            257266.80
# Western Dress    135605.96
# Name: Order_Amount_($), dtype: float64

# %%
# CALCULATE THE TOTAL AMOUNT FROM THE GROUPED DATASET
Total_Amount=grouped_dataset.sum()

# Calculate the percentage for the top 3 categories
top3_categories_percentage=(top3_categories/Total_Amount)*100
print(top3_categories_percentage)
# Out:
# Category
# Set              49.878257
# kurta            27.092678
# Western Dress    14.280617
# Name: Order_Amount_($), dtype: float64

# %%
#CREATING A BAR CHART FROM THE TOP THREE CATEGORIES
top3_categories=top3_categories.reset_index()
fig=px.bar(top3_categories,
           x='Category',
           y='Order_Amount_($)',
           title='Top 3 Category by total amount',
           labels={'Order_Amount_($)':'Total Amount','Category':'Product Category'},
           color='Order_Amount_($)',
           color_continuous_scale='reds')
fig.update_layout(xaxis_title='Product Category',yaxis_title='Total Amount')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Insight: Western Dress is identified as an underperforming category that can benefit from
# promotions to boost revenue

# %%
#BOTTOM THREE CATEGORIES
Bottom3_categories =grouped_dataset.nsmallest(3)

print(Bottom3_categories)
# Out:
# Category
# Dupatta      11.07
# Saree      1499.54
# Bottom     1823.10
# Name: Order_Amount_($), dtype: float64

# %% [markdown]
# # Preliminary Analysis
# --Based on the analysis, we can draw some preliminary insights about the Q2 2022
#  performance of Amazon India:

# %%
# Group by Month and Calculate Total Order Amount
group_dataset = dataset.groupby('Month')['Order_Amount_($)'].sum().reset_index()

#  Sort the DataFrame by Month in the order of appearance in the original DataFrame
months_order = dataset['Month'].unique()
group_dataset_sorted = group_dataset.set_index('Month').reindex(months_order).reset_index()

#  Create a Bar Chart for Total Order Amount by Month
fig = px.bar(group_dataset_sorted, x='Month', y='Order_Amount_($)',
              color='Order_Amount_($)',
              color_continuous_scale='sunsetdark',
              labels={'Order_Amount_($)': 'Total Order Amount', 'Month': 'Month'},
              title='Total Order Amount by Month (Order-wise)')
fig.update_layout(bargap=0.8, xaxis_title='Month', yaxis_title='Total Order Amount', width=1000)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#CALCULATE THE MONTH WISE REVENUE FROM DATASET
Month_wise_Revenue=dataset.groupby('Month')['Order_Amount_($)'].sum()
Month_wise_Revenue
# Out:
# Month
# April    348904.45
# June     283391.49
# May      317284.62
# Name: Order_Amount_($), dtype: float64

# %%
#  Group by Category and Calculate Sum of Amount
grouped_dataset = dataset.groupby('Category')['Order_Amount_($)'].sum().reset_index()

#  Create a Dashboard with a Pie Chart
fig = px.pie(grouped_dataset, names='Category', values='Order_Amount_($)',
             title='Total Amount by Category',
             labels={'Order_Amount_($)': 'Total Amount', 'Category': 'Product Category'})
fig.update_traces(textposition='inside', textinfo='percent+label')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#  Group by Category and Calculate the Average Selling Price
avg_price_by_category = dataset.groupby('Category')['Order_Amount_($)'].mean().reset_index()
top5_categories = avg_price_by_category.nlargest(5, 'Order_Amount_($)')

#  Create a Bar Chart for Top 5 Categories by Average Selling Price
fig = px.bar(top5_categories, x='Category', y='Order_Amount_($)',
             title='Top 5 Categories by Average Selling Price',
             labels={'Order_Amount_($)': 'Average Selling Price', 'Category': 'Product Category'},
             color='Order_Amount_($)', color_continuous_scale='blues')
fig.update_layout(xaxis_title='Product Category', yaxis_title='Average Selling Price')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Group by 'Status' and calculate the Qty
grouped_dataset = dataset.groupby('Status',as_index=False)['Qty'].sum()

fig = px.pie(grouped_dataset, names='Status', values='Qty',
             title='Total Amount by Category',
             labels={'Qty': 'Total Amount', 'Status': 'Order Status'})

fig.update_traces(textposition='inside', textinfo='percent+label')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The average order amount by customer type is  8.21 𝑓𝑜𝑟 𝑏𝑢𝑠𝑖𝑛𝑒𝑠𝑠 𝑐𝑢𝑠𝑡𝑜𝑚𝑒𝑟𝑠 𝑎𝑛𝑑
#  7.37 for regular customers.

# %%
# Group by 'customer_type' and calculate the average order amount
average_order_amount = dataset.groupby('Customer_type')['Order_Amount_($)'].mean().reset_index()

# Create a bar chart using Plotly Express
fig = px.bar(average_order_amount, x='Customer_type', y='Order_Amount_($)',
             title='Average Order Amount by Customer Type',
             labels={'Order_Amount_($)': 'Average Order Amount', 'Customer_type': 'Customer Type'},
            color ='Order_Amount_($)')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dataset
# Out:
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  128974  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
# Group by 'State' and calculate the total sales for each state
statewise_sales = dataset.groupby('ship-state')['Order_Amount_($)'].sum().reset_index()


# Create a bar graph using Plotly Express
fig = px.bar(statewise_sales, x='ship-state', y='Order_Amount_($)',
             title='State-wise Sales',
             labels={'Order_Amount_($)': 'Total Sales', 'ship-state': 'State'},
             color='Order_Amount_($)', color_continuous_scale='reds')


fig.update_layout(xaxis_title='ship-state', yaxis_title='Total Sales')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Sort the DataFrame by 'order_amount_($)' in descending order
statewise_sales_sorted = statewise_sales.sort_values(by='Order_Amount_($)', ascending=False)

# Select the top 5 states
top5_states = statewise_sales_sorted.head(5)

# Create a bar graph using Plotly Express for the top 5 states
fig = px.bar(top5_states, x='ship-state', y='Order_Amount_($)',
             title='Top 5 State-wise Sales',
             labels={'Order_Amount_($)': 'Total Sales', 'ship-state': 'State'},
             color='Order_Amount_($)', color_continuous_scale='reds')


fig.update_layout(xaxis_title='State', yaxis_title='Total Sales')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dataset
# Out:
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128970  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128971  128971  402-9551604-7544318 2022-05-31                       Shipped
# 128972  128972  407-9547469-3152358 2022-05-31                       Shipped
# 128973  128973  402-6184140-0545956 2022-05-31                       Shipped
# 128974  128974  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
# Create a new column indicating whether there is a promotion
dataset['Promotion Status'] = dataset['promotion-ids'].apply(lambda x: 'No Promotion' if x == 'No Promotion' else 'With Promotion')

# Aggregate data for plotting
agg_data = dataset.groupby('Promotion Status')['Order_Amount_($)'].sum().reset_index()

# Create a pie chart using Plotly Express
fig = px.pie(agg_data, values='Order_Amount_($)', names='Promotion Status',
             title='Sales with and without Promotion',
             color='Promotion Status', color_discrete_map={'No Promotion': 'blue', 'With Promotion': 'orange'})


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Step 1: Filter data for 'Western Dress' category
western_dress_sales = dataset[dataset['Category'] == 'Western Dress']

# Step 2: Group by State and Calculate Total Sales
statewise_western_dress_sales = western_dress_sales.groupby('ship-state')['Order_Amount_($)'].sum().reset_index()
# step 3: Create a Bar Chart for Western Dress Sales in All States
fig = px.bar(statewise_western_dress_sales, x='ship-state', y='Order_Amount_($)',
             title='Western Dress Sales in All States',
             labels={'Order_Amount_($)': 'Total Sales', 'ship-state': 'State'},
             color='Order_Amount_($)', color_continuous_scale='cividis')

# Customize the layout and appearance of the chart
fig.update_layout(xaxis_title='State', yaxis_title='Total Sales')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
